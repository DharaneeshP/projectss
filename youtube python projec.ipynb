# %%
import pandas as pd
import googleapiclient.discovery
import sqlite3
import pymongo
import psycopg2
import streamlit as st


api_key='AIzaSyD_nvYwsEZzHGzcTHck3OVs46D0SM439SA'
channel_id='UCnKhQkCUS1oCEvjuTfU4xIw'

# %%
youtube = googleapiclient.discovery.build("youtube", "v3", developerKey=api_key)

# %%
 #getting yt channel details   
def get_channel_info(channel_id):
        
        request = youtube.channels().list(

            part="snippet,contentDetails,statistics",
            id=channel_id)

        response = request.execute()

        for i in range(len(response["items"])):
            data = dict(channel_id=response['items'][i]["id"],
                        channel_name=response['items'][i]['snippet']["title"],
                        subscription_count=response['items'][i]['statistics']['subscriberCount'],
                        channel_views=response['items'][i]['statistics']["viewCount"],
                        total_videos=response['items'][i]['statistics']['videoCount'],
                        playlist_id=response['items'][i]['contentDetails']['relatedPlaylists']['uploads'],
                        channel_description=response['items'][i]["snippet"]['description'],
                        published_at=response['items'][i]["snippet"]['publishedAt']
                        )

        return data

# %%
get_channel_info(channel_id)
# Out:
# {'channel_id': 'UCnKhQkCUS1oCEvjuTfU4xIw',
#  'channel_name': 'Tech Boss',
#  'subscription_count': '4310000',
#  'channel_views': '1283807015',
#  'total_videos': '1612',
#  'playlist_id': 'UUnKhQkCUS1oCEvjuTfU4xIw',
# ...

# %%
 # getting playlist details
def get_playlist_info(channel_id):
    next_page_token=None
    all_data=[]
    while True:
        request = youtube.playlists().list(
            part="snippet,contentDetails",
            channelId=channel_id,
            maxResults=50,
            pageToken=next_page_token
        )
        response = request.execute()
        
        for item in response ["items"]:
            data=dict(playlist_id=item["id"],
                      Title=item["snippet"]["title"],
                      Channel_Id=item["snippet"]["channelId"],
                      Channel_Name=item["snippet"]["channelTitle"],
                      PublishedAt=item["snippet"]["publishedAt"],
                      video_Count=item["contentDetails"]["itemCount"])
            all_data.append(data)
            
        next_page_token=response.get("nextPageToken")
        if next_page_token is None:
            break
            
    return all_data

# %%
 get_playlist_info(channel_id)
# Out:
# [{'playlist_id': 'PLWvLfbW5qLgHuIICfPBhyFlQR12BhE1vl',
#   'Title': 'RANT Videos',
#   'Channel_Id': 'UCnKhQkCUS1oCEvjuTfU4xIw',
#   'Channel_Name': 'Tech Boss',
#   'PublishedAt': '2023-11-30T14:54:38Z',
#   'video_Count': 1},
#  {'playlist_id': 'PLWvLfbW5qLgFv1uGjFoGyliqGZT8W2vny',
#   'Title': 'Techboss Vlog',
#   'Channel_Id': 'UCnKhQkCUS1oCEvjuTfU4xIw',
#   'Channel_Name': 'Tech Boss',
#   'PublishedAt': '2022-12-16T06:32:42Z',
#   'video_Count': 2},
#  {'playlist_id': 'PLWvLfbW5qLgGvkTDguSZhJFkGtmsz5idv',
#   'Title': 'Concept Review',
#   'Channel_Id': 'UCnKhQkCUS1oCEvjuTfU4xIw',
#   'Channel_Name': 'Tech Boss',
#   'PublishedAt': '2022-07-31T16:02:04Z',
#   'video_Count': 6},
#  {'playlist_id': 'PLWvLfbW5qLgEgFTfHFjjdFDZnmIl0JtsD',
#   'Title': 'TV Unboxing & Review',
#   'Channel_Id': 'UCnKhQkCUS1oCEvjuTfU4xIw',
#   'Channel_Name': 'Tech Boss',
#   'PublishedAt': '2022-06-12T18:28:38Z',
#   'video_Count': 2},
#  {'playlist_id': 'PLWvLfbW5qLgFeby350Y2jT7HWSPqeTn9b',
# ...

# %%
def get_video_ids_from_channel(channel_id):
    video_ids = []

    request = youtube.search().list(
        part="id",
        channelId=channel_id,
        maxResults=100
    )

    response = request.execute()

    for item in response.get("items", []):
        video_id = item["id"].get("videoId")
        if video_id:
            video_ids.append(video_id)

    return video_ids

# %%
 video_ids=get_video_ids_from_channel(channel_id)

# %%
video_ids
# Out:
# ['6rBtYBtrhwA',
#  'Pel70b0uj3E',
#  'uuwKW2J9wSM',
#  'kBVp0FSxe9M',
#  'm2sS-qfYlKQ',
#  '_6FvO9IGLXQ',
#  '5AEV336K4OY',
#  'N-TAv5bLmEA',
#  'JDP0R4t7SAs',
#  'DoQb1vRA4B4',
#  'qvjkuhTJP38',
#  'yAZZVPXdRqY',
#  'et88HA3Czqw',
#  'ACJDeHCBjaM',
#  '3ilfFw3ANks',
#  '0CyLVxnYMxc',
#  'NFmSUE-16qc',
#  'sOjYYhXKcGw',
#  'YBNwAHK-QMA',
#  'iX4QSRBX4N8',
#  'taGkoUtVD9Y',
#  '--oN0eaScak',
#  'vUIcG5gLxQs',
#  'wxw-zTOGKb8',
#  'yIMXtthVawg',
#  'B4DoZZ_A7NY',
#  'Gl9GEYryA70',
#  '9jC7RXHshNk',
#  'BFpqum0nYkc',
#  'BkgloynmW6o',
#  'jrkzlQ18vDM',
#  'kJm6dsZzs1U',
#  'XwS5jWGuxHY',
#  'a_yyX-RvvkI',
#  'hwyaPTCc42o',
#  'lUz9Uu8NGCw',
#  'Z07jnNe9WaM',
#  'ldzsdpftZjE',
#  'd6mOK0pmZ6I',
#  'mPrdLqmQt5g',
#  'V5oP-dVPRpE',
#  'UK_Zv1KsE2c',
#  'ItF5I9zM_go',
#  '4QfaJ2W-wrY',
#  'po8FfLEGU5I',
#  'qgVTYx3rNgo',
#  '5McBgXK2oYg',
#  'WdDTR_bG6lA',
#  'EzoEmy021fg']

# %%
#getting all video informations
def get_videos_info (video_ids):
        video_data = []
        for video in video_ids:
            request = youtube.videos().list(
                part="snippet,contentDetails,statistics",
                id=video_ids
            )
    
            response = request.execute()
            
            for item in response["items"]:
                data=dict(Channel_Name=item["snippet"]["channelTitle"],
                          Channel_Id=item["snippet"]["channelId"],
                          video_Id=item["id"],
                          Title=item["snippet"]["title"],
                          Tags=item["snippet"].get("tags"),
                          Thumbnail=item["snippet"]["thumbnails"]["default"]["url"],
                          Description=item["snippet"].get("description"),
                          Published_At=item["snippet"]["publishedAt"],
                          Duration=item["contentDetails"]["duration"],
                          Views=item["statistics"].get("viewCount"),
                          Comment_Count=item["statistics"].get("commentcount"),
                          Like_Count=item["statistics"].get("likeCount"),
                          Favorite_Count=item["statistics"]["favoriteCount"],
                          Definition=item["contentDetails"]["definition"],
                          Caption_Status=item["contentDetails"]["caption"]                      
                         )
                video_data.append(data)
        return video_data

# %%
 get_videos_info (video_ids)
# Out:
# [{'Channel_Name': 'Tech Boss',
#   'Channel_Id': 'UCnKhQkCUS1oCEvjuTfU4xIw',
#   'video_Id': '6rBtYBtrhwA',
#   'Title': "😳 நீ ஒரு Artist 'nu நிருபிச்சுட்ட..! 🤩 #shorts #agaro #waterwash #techboss",
#   'Tags': ['Techboss'],
#   'Thumbnail': 'https://i.ytimg.com/vi/6rBtYBtrhwA/default.jpg',
#   'Description': '---\nMedia Partner : Adada Creators\nEmail : techboss@adadacreators.com\n\n😄 Subscribe😄 : http://bit.ly/2JmvIXb\nYou can also follow me on:\n📞 TeleGram: https://bit.ly/3dCwOJk\n🌈 Instagram: http://bit.ly/2JkdyVI\n🐦 Twitter: http://bit.ly/2xw0mZi\n😊 Facebook: http://bit.ly/2sk5fPV',
#   'Published_At': '2023-05-13T11:34:00Z',
#   'Duration': 'PT42S',
#   'Views': '1874206',
#   'Comment_Count': None,
#   'Like_Count': '147263',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Tech Boss',
#   'Channel_Id': 'UCnKhQkCUS1oCEvjuTfU4xIw',
#   'video_Id': 'Pel70b0uj3E',
# ...

# %%
  #  Getting All commment details
def get_comments_info(video_ids):
        all_comments = []

        for video_id in video_ids:
            
            try:
                request = youtube.commentThreads().list(
                    part="snippet,replies",
                    videoId=video_id,
                    maxResults=50
                )

                response = request.execute()
                for i in response['items']:
                    comments_in_video = dict(Comment_Id=i["id"],
                                             Comment_Author=i["snippet"]["topLevelComment"]["snippet"]["authorDisplayName"],
                                             Comment_Text=i["snippet"]["topLevelComment"]["snippet"]["textDisplay"],
                                             Comment_PublishedAt=i["snippet"]["topLevelComment"]["snippet"]["publishedAt"],
                                             Video_Id=i["snippet"]["topLevelComment"]["snippet"]["videoId"])

                    all_comments.append(comments_in_video)
                    comments = {"comments": all_com}


            except:
                comments = {"comments": None}

                
            
            
            
        return all_comments

# %%
 get_comments_info(video_ids)
# Out:
# [{'Comment_Id': 'UgwD_t9Se2EGXT6QKol4AaABAg',
#   'Comment_Author': '@psehu',
#   'Comment_Text': 'Bro bullet wash pannunathu vera prosser',
#   'Comment_PublishedAt': '2023-11-23T15:31:53Z',
#   'Video_Id': '6rBtYBtrhwA'},
#  {'Comment_Id': 'UgyeBXfbmjNUPrb7SHt4AaABAg',
#   'Comment_Author': '@jingpinguu1995',
#   'Comment_Text': 'Am using this! Good to Go🎉',
#   'Comment_PublishedAt': '2023-12-01T08:46:31Z',
#   'Video_Id': 'Pel70b0uj3E'},
#  {'Comment_Id': 'Ugxaj4-uMMPqOHiBub14AaABAg',
#   'Comment_Author': '@user-Queen18',
#   'Comment_Text': '😢😢😢😢😢',
#   'Comment_PublishedAt': '2023-12-05T19:34:32Z',
#   'Video_Id': 'uuwKW2J9wSM'},
#  {'Comment_Id': 'Ugyjn8pkGY17QX7SC5F4AaABAg',
#   'Comment_Author': '@jayavenkatraman3217',
#   'Comment_Text': 'Fine da😂😂😂😂',
#   'Comment_PublishedAt': '2023-11-30T09:04:16Z',
#   'Video_Id': 'kBVp0FSxe9M'},
#  {'Comment_Id': 'UgyW4bNaNwsUUNZ9Lgp4AaABAg',
#   'Comment_Author': '@user-in2tn9mn5h',
# ...

# %%
client = pymongo.MongoClient("mongodb://localhost:27017/")
db = client["youtube"]


#Function to insert details in MongoDB

def get_all_youtube_data(channel_id):
    Channel = get_channel_info(channel_id)
    Playlist = get_playlist_info(channel_id) 
    Videodetails =  get_videos_info (video_ids)
    Comment = get_comments_info(video_ids)
    
    collection = db["data"]
    collection.insert_one({"Channel_Info":Channel,"Playlist_Info":Playlist,"Video_Info":Videodetails,"Comment_Info":Comment})
    
    return "inserted data successfully in MongoDB"

# %%
get_all_youtube_data(channel_id)
# Out:
# 'inserted data successfully in MongoDB'

# %%
# sql python connectivity
import psycopg2
import pandas as pd

# %%
import psycopg2

# Function to create channel_details table in PostgreSQL
def channel_table():
    
    conn= psycopg2.connect(user="postgres",
                           password="sumathiamma123",
                           host="localhost",
                           port="5432",
                           database="youtube")
    cursor=conn.cursor()
    
    drop_query='''drop table if exists channel_details'''
    cursor.execute(drop_query)
    conn.commit() 
    
    create_query = '''create table if not exists channel_details (
                                                                      channel_id varchar(255) primary key,
                                                                      channel_name varchar(255),
                                                                      subscription_count bigint,
                                                                      channel_views bigint,
                                                                      total_videos bigint,
                                                                      playlist_id varchar(255),
                                                                      channel_description text,
                                                                      published_at varchar(255))'''

    cursor.execute(create_query)
    conn.commit()
        
    
    channel_list=[]
    db = client["youtube"]   
    collection = db["data"]
    for i in collection.find({},{"_id":0,"Channel_Info":1}):
        channel_list.append(i["Channel_Info"])
    df_channel_list=pd.DataFrame(channel_list)

    
    for index,row in df_channel_list.iterrows():
        insert_query = '''insert into channel_details(channel_id, 
                                                        channel_name, 
                                                        subscription_count, 
                                                        channel_views,
                                                        total_videos,
                                                        playlist_id,
                                                        channel_description,
                                                        published_at)
                                            
                                            values(%s,%s,%s,%s,%s,%s,%s,%s)'''
        values=(row['channel_id'],
                row['channel_name'],
                row['subscription_count'],
                row['channel_views'],
                row['total_videos'],
                row['playlist_id'],
                row['channel_description'],
                row['published_at'])

        try:
            cursor.execute(insert_query,values)
            conn.commit()

        except:
            print("channel details already inserted")

# %%
channel_table()
# Out:
# channel details already inserted

# %%
def playlist_table():
    conn= psycopg2.connect(user="postgres",
                           password="sumathiamma123",
                           host="localhost",
                           port="5432",
                           database="youtube")
    cursor=conn.cursor()
    
    drop_query='''drop table if exists playlist_details'''
    cursor.execute(drop_query)
    conn.commit() 
    
    create_query='''create table if not exists playlist_details(playlist_id varchar(255)primary key,
                                                                    Title varchar(255),
                                                                    Channel_Id varchar(255),
                                                                    Channel_Name varchar(255),
                                                                    PublishedAt varchar(255),
                                                                    video_Count int)'''

                                                            
    cursor.execute(create_query)
    conn.commit()
        
  

    playlist_list=[]
    db = client["youtube"]   
    collection = db["data"]
    for j in collection.find({},{"_id":0,"Playlist_Info":1}):
        for i in range(len(j["Playlist_Info"])):
            playlist_list.append(j["Playlist_Info"][i])
    df_playlist_list=pd.DataFrame(playlist_list)


    for index,row in df_playlist_list.iterrows():
            insert_query = '''insert into playlist_details(playlist_id,
                                                            Title,
                                                            Channel_Name,
                                                            PublishedAt,
                                                            video_Count)

                                                values(%s,%s,%s,%s,%s)'''
            values=(row['playlist_id'],
                    row['Title'],
                    row['Channel_Name'],
                    row['PublishedAt'],
                    row['video_Count'])

            
            cursor.execute(insert_query,values)
            conn.commit()

# %%
playlist_table()
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 playlist_table()
#
# Cell In[22], line 50, in playlist_table()
#      36 insert_query = '''insert into playlist_details(playlist_id,
#      37                                                 Title,
#      38                                                 Channel_Name,
#    (...)
#      41
#      42                                     values(%s,%s,%s,%s,%s)'''
#      43 values=(row['playlist_id'],
#      44         row['Title'],
#      45         row['Channel_Name'],
#      46         row['PublishedAt'],
#      47         row['video_Count'])
# ---> 50 cursor.execute(insert_query,values)
#      51 conn.commit()
#
# UniqueViolation: duplicate key value violates unique constraint "playlist_details_pkey"
# DETAIL:  Key (playlist_id)=(PLWvLfbW5qLgHuIICfPBhyFlQR12BhE1vl) already exists.

# %%
def playlisttable():
    sqldb = psycopg2.connect(host="localhost",
                            user="postgres",
                            password="kavin",
                            database="YouTube_Data",
                            port="5432")
    cursor=sqldb.cursor()

    drop_query = '''drop table if exists playlist'''
    cursor.execute(drop_query)
    sqldb.commit()

    try:
        create_query='''create table if not exists playlist(Channel_Name varchar(255),
                                                            Channel_Id varchar(255),
                                                            Playlist_Id varchar(255)primary key,
                                                            Playlist_Name varchar(255),
                                                            VideoCount int)'''
                                                            
                                                            
        cursor.execute(create_query)
        sqldb.commit()


    except:
        print("playlist table created")



    playlist_list = []
    db = client['Youtube_Project']
    coll1 = db["ChannelDetails"]
    for pl in coll1.find({},{"_id":0,"Playlist_Info":1}):
        for i in range(len(pl["Playlist_Info"])):
            playlist_list.append(pl["Playlist_Info"][i])
    DF_playlist_list = pd.DataFrame(playlist_list)

    for index,row in DF_playlist_list.iterrows():
            insert_query = '''insert into playlist(Channel_Name,
                                                Channel_Id,
                                                Playlist_Id,
                                                Playlist_Name,
                                                VideoCount)
                                            
                                                values(%s,%s,%s,%s,%s)'''
            values=(row['Channel_Name'],
                    row['Channel_Id'],
                    row['Playlist_Id'],
                    row['Playlist_Name'],
                    row['VideoCount'])

            
            cursor.execute(insert_query,values)
            sqldb.commit()

# %%
(playlist_id
                      Title
                      Channel_Id
                      Channel_Name
                      PublishedAt
                      video_Count)
